# %% [markdown]
# Git clone the repo and install the requirements. (ignore the pip errors about protobuf)

# %%
#@title Environment Setup

from pathlib import Path

OPTIONS = {}

WORKSPACE = 'ComfyUI'
USE_GOOGLE_DRIVE = True  #@param {type:"boolean"}
UPDATE_COMFY_UI = True  #@param {type:"boolean"}

OPTIONS['USE_GOOGLE_DRIVE'] = USE_GOOGLE_DRIVE
OPTIONS['UPDATE_COMFY_UI'] = UPDATE_COMFY_UI

if OPTIONS['USE_GOOGLE_DRIVE']:
    # !echo "Mounting Google Drive..."
    # %cd /

    from google.colab import drive
    drive.mount('/content/drive')

    WORKSPACE = "/content/drive/MyDrive/ComfyUI"

    # %cd /content/drive/MyDrive

![ ! -d $WORKSPACE ] && echo "-= Initial setup ComfyUI (Original)=-" && git clone https://github.com/comfyanonymous/ComfyUI
# %cd $WORKSPACE

if OPTIONS['UPDATE_COMFY_UI']:
  # !echo "-= Updating ComfyUI =-"
  # !git pull
  # !rm "/content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-impact-pack.py"

# %cd custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Impact-Pack
# %cd $WORKSPACE

# !echo -= Install dependencies =-
# !pip -q install xformers -r requirements.txt
# Out:
# Mounting Google Drive...
# /
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive
# /content/drive/MyDrive/ComfyUI
# -= Updating ComfyUI =-
# Already up to date.
# rm: cannot remove '/content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-impact-pack.py': No such file or directory
# /content/drive/MyDrive/ComfyUI/custom_nodes
# fatal: destination path 'ComfyUI-Impact-Pack' already exists and is not an empty directory.
# /content/drive/MyDrive/ComfyUI
# -= Install dependencies =-

# %% [markdown]
# ### Run ComfyUI with localtunnel (Recommended Way)

# %%
# !npm install -g localtunnel

import subprocess
import threading
import time
import socket
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)")
  p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
  for line in p.stdout:
    print(line.decode(), end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server
# Out:
# ⠙⠹⠸⠼⠴⠦
# changed 22 packages in 909ms
# ⠦
# ⠦3 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦[START] Security scan
# [ComfyUI-Manager] Using standalone `uv` for pip operations.
# Using Python 3.12.13 environment at: /usr
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-03-27 00:07:35.274
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/drive/MyDrive/ComfyUI
# ** ComfyUI Base Folder Path: /content/drive/MyDrive/ComfyUI
# ** User directory: /content/drive/MyDrive/ComfyUI/user
# ** ComfyUI-Manager config path: /content/drive/MyDrive/ComfyUI/user/__manager/config.ini
# ** Log path: /content/drive/MyDrive/ComfyUI/user/comfyui.log
# Using Python 3.12.13 environment at: /usr
# Using Python 3.12.13 environment at: /usr
#
# Prestartup times for custom nodes:
# ...

# %% [markdown]
# ### Run ComfyUI with colab iframe (use only in case the previous way with localtunnel doesn't work)
#
# You should see the ui appear in an iframe. If you get a 403 error, it's your firefox settings or an extension that's messing things up.
#
# If you want to open it in another window use the link.
#
# Note that some UI features like live image previews won't work because the colab iframe blocks websockets.

# %%
import threading
import time
import socket
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  from google.colab import output
  output.serve_kernel_port_as_iframe(port, height=1024)
  print("to open it in a window you can open this link here:")
  output.serve_kernel_port_as_window(port)

threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server
# Out:
# python3: can't open file '/content/drive/MyDrive/ComfyUI/custom_nodes/main.py': [Errno 2] No such file or directory

# %%
# %cd /content/drive/MyDrive/ComfyUI/custom_nodes

# Video araçlarını yükle
# !git clone https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git

# Hareket (Motion) araçlarını yükle
# !git clone https://github.com/Kosinkadink/ComfyUI-AnimateDiff-Evolved.git

# Gerekli kütüphaneleri yükle
# !pip install ffmpeg-python imageio-ffmpeg
# Out:
# /content/drive/MyDrive/ComfyUI/custom_nodes
# fatal: destination path 'ComfyUI-VideoHelperSuite' already exists and is not an empty directory.
# fatal: destination path 'ComfyUI-AnimateDiff-Evolved' already exists and is not an empty directory.
# ...

# %%
# !curl ipv4.icanhazip.com
# Out:
# 34.125.106.188

# %%
# 1. Ana klasöre geri dön
# %cd /content/drive/MyDrive/ComfyUI

# 2. ComfyUI'ı başlat (IP sormaması için share modunda)
# !python main.py --listen --share
# Out:
# /content/drive/MyDrive/ComfyUI
# usage: main.py [-h] [--listen [IP]] [--port PORT] [--tls-keyfile TLS_KEYFILE]
#                [--tls-certfile TLS_CERTFILE] [--enable-cors-header [ORIGIN]]
#                [--max-upload-size MAX_UPLOAD_SIZE]
#                [--base-directory BASE_DIRECTORY]
#                [--extra-model-paths-config PATH [PATH ...]]
#                [--output-directory OUTPUT_DIRECTORY]
#                [--temp-directory TEMP_DIRECTORY]
#                [--input-directory INPUT_DIRECTORY] [--auto-launch]
#                [--disable-auto-launch] [--cuda-device DEVICE_ID]
#                [--default-device DEFAULT_DEVICE_ID]
#                [--cuda-malloc | --disable-cuda-malloc]
#                [--force-fp32 | --force-fp16]
#                [--fp32-unet | --fp64-unet | --bf16-unet | --fp16-unet | --fp8_e4m3fn-unet | --fp8_e5m2-unet | --fp8_e8m0fnu-unet]
#                [--fp16-vae | --fp32-vae | --bf16-vae] [--cpu-vae]
# ...

# %%
# Eklentinin olduğu klasöre git ve gerekli yardımcı kütüphaneleri kur
# %cd /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_controlnet_aux
# !pip install -r requirements.txt
# !pip install opencv-python-headless

# Şimdi geri dön ve ComfyUI'ı tekrar başlat
# %cd /content/drive/MyDrive/ComfyUI
# !python main.py --listen --share
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_controlnet_aux'
# /content/drive/MyDrive/ComfyUI
# ...
# /content/drive/MyDrive/ComfyUI
# usage: main.py [-h] [--listen [IP]] [--port PORT] [--tls-keyfile TLS_KEYFILE]
#                [--tls-certfile TLS_CERTFILE] [--enable-cors-header [ORIGIN]]
#                [--max-upload-size MAX_UPLOAD_SIZE]
#                [--base-directory BASE_DIRECTORY]
#                [--extra-model-paths-config PATH [PATH ...]]
#                [--output-directory OUTPUT_DIRECTORY]
#                [--temp-directory TEMP_DIRECTORY]
#                [--input-directory INPUT_DIRECTORY] [--auto-launch]
#                [--disable-auto-launch] [--cuda-device DEVICE_ID]
#                [--default-device DEFAULT_DEVICE_ID]
#                [--cuda-malloc | --disable-cuda-malloc]
#                [--force-fp32 | --force-fp16]
# ...

# %%
# AnimateDiff modelini doğrudan indir ve doğru klasöre koy
# !mkdir -p /content/drive/MyDrive/ComfyUI/models/animatediff_models
# !wget -O /content/drive/MyDrive/ComfyUI/models/animatediff_models/mm_sd_v15_v2.ckpt https://huggingface.co/guoyww/AnimateDiff/resolve/main/mm_sd_v15_v2.ckpt
# Out:
# --2026-03-27 00:06:46--  https://huggingface.co/guoyww/AnimateDiff/resolve/main/mm_sd_v15_v2.ckpt
# Resolving huggingface.co (huggingface.co)... 18.164.174.118, 18.164.174.23, 18.164.174.55, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.118|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: /guoyww/animatediff/resolve/main/mm_sd_v15_v2.ckpt [following]
# --2026-03-27 00:06:46--  https://huggingface.co/guoyww/animatediff/resolve/main/mm_sd_v15_v2.ckpt
# Reusing existing connection to huggingface.co:443.
# HTTP request sent, awaiting response... 302 Found
# ...
